# %% [markdown]
# <a href="https://colab.research.google.com/github/JManuelRG/RDD/blob/main/M%C3%A9todos%20Num%C3%A9ricos/Runge_Kutta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Runge Kutta 4to Orden
# # Video Explicación: https://youtu.be/9OOmUdrHZFM
#
# ![image.png](data:image/png;base64,...)

# %%
def f1(x, y):
  return x+y

# %%
h = 0.2
xo = 0
yo = 1

# %%
import numpy as np
X = np.linspace(start = xo, stop = 10, num=100)
X
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
import numpy as np
def RK4(xo, yo, h):
  global X, Y
  X = [xo]
  Y = [yo]

  for i in range(0,100):
    X.append(X[i]+h)
    p = f1(X[i], Y[i])*h
    q = f1(X[i]+0.5*h, Y[i]+0.5*p)*h
    r = f1(X[i]+0.5*h, Y[i]+0.5*q)*h
    s = f1(X[i]+h, Y[i]+r)*h
    Y.append(Y[i]+(1/6)*(p+2*q+2*r+s))
  return X, Y

# %%
RK4(xo= 0, yo = 1, h = 0.2)

# %%
X
# Out:
# array([ 0. ,  0.2,  0.4,  0.6,  0.8,  1. ,  1.2,  1.4,  1.6,  1.8,  2. ,
#         2.2,  2.4,  2.6,  2.8,  3. ,  3.2,  3.4,  3.6,  3.8,  4. ,  4.2,
#         4.4,  4.6,  4.8,  5. ,  5.2,  5.4,  5.6,  5.8,  6. ,  6.2,  6.4,
#         6.6,  6.8,  7. ,  7.2,  7.4,  7.6,  7.8,  8. ,  8.2,  8.4,  8.6,
#         8.8,  9. ,  9.2,  9.4,  9.6,  9.8, 10. , 10.2, 10.4, 10.6, 10.8,
#        11. , 11.2, 11.4, 11.6, 11.8, 12. , 12.2, 12.4, 12.6, 12.8, 13. ,
#        13.2, 13.4, 13.6, 13.8, 14. , 14.2, 14.4, 14.6, 14.8, 15. , 15.2,
#        15.4, 15.6, 15.8, 16. , 16.2, 16.4, 16.6, 16.8, 17. , 17.2, 17.4,
#        17.6, 17.8, 18. , 18.2, 18.4, 18.6, 18.8, 19. , 19.2, 19.4, 19.6,
#        19.8, 20. ])

# %%
X = np.array(X)
Yreal = -1 -X +2*np.exp(X)

import pandas as pd
df = pd.DataFrame(list(zip(X, Y, Yreal)), columns =['X', 'Y', 'Yreal'])
df
# Out:
#         X             Y         Yreal
# 0     0.0  1.000000e+00  1.000000e+00
# 1     0.2  1.242800e+00  1.242806e+00
# 2     0.4  1.583636e+00  1.583649e+00
# 3     0.6  2.044213e+00  2.044238e+00
# 4     0.8  2.651042e+00  2.651082e+00
# ..    ...           ...           ...
# 96   19.2  4.359030e+08  4.359975e+08
# 97   19.4  5.324120e+08  5.325286e+08
# 98   19.6  6.502880e+08  6.504319e+08
# 99   19.8  7.942617e+08  7.944393e+08
# 100  20.0  9.701113e+08  9.703304e+08
#
# [101 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(X, Y, 'o', label = 'RK4')
plt.plot(X, Yreal, label ='Solución Real')
plt.grid()
plt.legend()
plt.title('RK4 vs Solución Real')
plt.xlabel('X')
plt.ylabel('Función Solución Y')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(X, Y, 'o', label = 'RK4')
plt.plot(X, Yreal, label ='Solución Real')
plt.grid()
plt.legend()
xlim=(0,5)
ylim=(0,100)
plt.xlim(xlim)
plt.ylim(ylim)
plt.title('RK4 vs Solución Real')
plt.xlabel('X')
plt.ylabel('Función Solución Y')
plt.show()
